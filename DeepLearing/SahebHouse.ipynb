# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sklearn

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data= pd.read_csv("HousingData.csv")
target = data ['MEDV'] #Median value of owner-occupied homes in $1000

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
data.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
data.shape
# Out:
# (506, 14)

# %%
data.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
data.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
data[data.isnull().any(axis=1)]
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 4     0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# 6     0.08829  12.5   7.87   NaN  0.524  6.012  66.6  5.5605    5  311
# 9     0.17004  12.5   7.87   NaN  0.524  6.004  85.9  6.5921    5  311
# 14    0.63796   0.0   8.14   NaN  0.538  6.096  84.5  4.4619    4  307
# 35    0.06417   0.0   5.96   0.0  0.499  5.933  68.2  3.3603    5  279
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 473   4.64689   0.0  18.10   0.0  0.614  6.980  67.6  2.5329   24  666
# 479  14.33370   0.0  18.10   NaN  0.614  6.229  88.0  1.9512   24  666
# 482   5.73116   0.0  18.10   NaN  0.532  7.061  77.0  3.4106   24  666
# 501   0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 505   0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 4       18.7  396.90    NaN  36.2
# 6       15.2  395.60  12.43  22.9
# 9       15.2  386.71  17.10  18.9
# 14      21.0  380.02  10.26  18.2
# 35      19.2  396.90    NaN  18.9
# ..       ...     ...    ...   ...
# 473     20.2  374.68    NaN  29.8
# 479     20.2  383.32  13.11  21.4
# 482     20.2  395.28   7.01  25.0
# 501     21.0  391.99    NaN  22.4
# 505     21.0  396.90   7.88  11.9
#
# [112 rows x 14 columns]

# %%
data.fillna(value=data.mean(), inplace=True)
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.545770   22.921051    6.699165    0.250233    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.083235    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.290250    0.000000    9.900000    0.000000    0.538000    6.208500
# 75%      3.611874   11.211934   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.439466    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.925000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     74.450000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.575000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.715432   22.532806
# std      7.012739    9.197104
# min      1.730000    5.000000
# 25%      7.230000   17.025000
# 50%     11.995000   21.200000
# 75%     16.570000   25.000000
# max     37.970000   50.000000

# %%
corr = data.corr()
corr.shape
# Out:
# (14, 14)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr, cbar=True, square= True,annot=True)
# Out:
# <Axes: >

# %%
X = data
y = target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 4)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.layers import Dense, Activation,Dropout
from keras.models import Sequential

model = Sequential()

model.add(Dense(128,activation  = 'relu',input_dim =14))
model.add(Dense(64,activation  = 'relu'))
model.add(Dense(32,activation  = 'relu'))
model.add(Dense(16,activation  = 'relu'))
model.add(Dense(1))
model.compile(optimizer = 'adam',loss = 'mean_squared_error')

# %%
model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 3ms/step - loss: 560.5226
# Epoch 2/100
# 12/12 [==============================] - 0s 2ms/step - loss: 511.9918
# Epoch 3/100
# 12/12 [==============================] - 0s 3ms/step - loss: 423.4930
# Epoch 4/100
# 12/12 [==============================] - 0s 2ms/step - loss: 267.6470
# Epoch 5/100
# 12/12 [==============================] - 0s 3ms/step - loss: 92.8175
# Epoch 6/100
# 12/12 [==============================] - 0s 3ms/step - loss: 46.8437
# Epoch 7/100
# 12/12 [==============================] - 0s 3ms/step - loss: 26.6230
# Epoch 8/100
# 12/12 [==============================] - 0s 2ms/step - loss: 18.5156
# Epoch 9/100
# 12/12 [==============================] - 0s 2ms/step - loss: 14.3013
# Epoch 10/100
# 12/12 [==============================] - 0s 2ms/step - loss: 12.1901
# Epoch 11/100
# 12/12 [==============================] - 0s 3ms/step - loss: 10.9225
# Epoch 12/100
# 12/12 [==============================] - 0s 2ms/step - loss: 9.2028
# Epoch 13/100
# 12/12 [==============================] - 0s 2ms/step - loss: 8.3748
# Epoch 14/100
# 12/12 [==============================] - 0s 2ms/step - loss: 7.5115
# Epoch 15/100
# 12/12 [==============================] - 0s 2ms/step - loss: 6.7583
# Epoch 16/100
# 12/12 [==============================] - 0s 2ms/step - loss: 6.2047
# Epoch 17/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.8877
# Epoch 18/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.3985
# Epoch 19/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.1360
# Epoch 20/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.8291
# Epoch 21/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.6010
# Epoch 22/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.4340
# Epoch 23/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.2008
# Epoch 24/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.0676
# Epoch 25/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.9045
# Epoch 26/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.7032
# Epoch 27/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.5271
# Epoch 28/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.4280
# Epoch 29/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.2167
# Epoch 30/100
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0939
# Epoch 31/100
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1594
# Epoch 32/100
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9265
# Epoch 33/100
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7829
# Epoch 34/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.7197
# Epoch 35/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6138
# Epoch 36/100
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6666
# Epoch 37/100
# 12/12 [==============================] - 0s 2ms/step - loss: 2.5568
# Epoch 38/100
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4119
# Epoch 39/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5585
# Epoch 40/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2127
# Epoch 41/100
# 12/12 [==============================] - 0s 2ms/step - loss: 2.5189
# Epoch 42/100
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1990
# Epoch 43/100
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2478
# Epoch 44/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.9085
# Epoch 45/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8330
# Epoch 46/100
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8036
# Epoch 47/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6911
# Epoch 48/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6855
# Epoch 49/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6177
# Epoch 50/100
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5208
# Epoch 51/100
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4770
# Epoch 52/100
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5442
# Epoch 53/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4415
# Epoch 54/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4250
# Epoch 55/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3766
# Epoch 56/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3627
# Epoch 57/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3011
# Epoch 58/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2525
# Epoch 59/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2178
# Epoch 60/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2040
# Epoch 61/100
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1277
# Epoch 62/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1028
# Epoch 63/100
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0948
# Epoch 64/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0671
# Epoch 65/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0744
# Epoch 66/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9800
# Epoch 67/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9318
# Epoch 68/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0566
# Epoch 69/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9812
# Epoch 70/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9266
# Epoch 71/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9196
# Epoch 72/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8570
# Epoch 73/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8339
# Epoch 74/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0797
# Epoch 75/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8781
# Epoch 76/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7840
# Epoch 77/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7592
# Epoch 78/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7275
# Epoch 79/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6925
# Epoch 80/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7493
# Epoch 81/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6915
# Epoch 82/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6754
# Epoch 83/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6189
# Epoch 84/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5999
# Epoch 85/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6489
# Epoch 86/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5891
# Epoch 87/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5567
# Epoch 88/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5959
# Epoch 89/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6167
# Epoch 90/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6012
# Epoch 91/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5483
# Epoch 92/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5901
# Epoch 93/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5156
# Epoch 94/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4813
# Epoch 95/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4752
# Epoch 96/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4676
# Epoch 97/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6130
# Epoch 98/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4857
# Epoch 99/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4282
# Epoch 100/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4128

# %%
y_pred = model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.9863760757670059

# %%
from sklearn.metrics import mean_squared_error
rmse = (np.sqrt(mean_squared_error(y_test, y_pred)))
print(rmse)
# Out:
# 1.1927326411110635

# %%
sns.regplot(x= y_test,y=y_pred,data = data)
# Out:
# <Axes: xlabel='MEDV'>
